# %% [markdown]
# <a href="https://colab.research.google.com/github/ib1905/MIPT_Python_professional_development_program/blob/main/Python_lesson_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' Pandas is a library based on Numpy; Series and DataFrame are main structures.
DataFrame is a whole table; Series is an array-type data structure.
For every Series there is an Index. 
'''

# %%
# Series

import pandas as pd

s = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']) # creating Series from list with custom indices
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
import numpy as np

x = pd.Series(np.random.randint(-5, 6, 10), index=list('abcdefghij'))
x
# Out:
# a    0
# b    5
# c    0
# d    5
# e    0
# f   -4
# g   -4
# h   -3
# i   -5
# j   -4
# dtype: int64

# %%
x.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')

# %%
y = pd.Series(np.random.randint(-5, 6, 10), index=['a'] * 5 + ['b'] * 5)
y
# Out:
# a   -4
# a    3
# a   -4
# a   -3
# a    1
# b    1
# b    4
# b   -1
# b    4
# b    2
# dtype: int64

# %%
y['a']
# Out:
# a   -4
# a    3
# a   -4
# a   -3
# a    1
# dtype: int64

# %%
y[-2]
# Out:
# 4

# %%
d = {'Moscow': 1000, 'London': 300, 'Prague': None}
cities = pd.Series(d)
cities
# Out:
# Moscow    1000.0
# London     300.0
# Prague       NaN
# dtype: float64

# %%
import numpy as np; import pandas as pd
data = {i: np.random.randint(10) for i in 'abcdefghij'}
print(type(data))
z = pd.Series(data)
z
# Out:
# <class 'dict'>
# a    5
# b    5
# c    9
# d    6
# e    9
# f    6
# g    9
# h    2
# i    9
# j    0
# dtype: int64

# %%
z1 = pd.Series(data, index=list('facdxyz'))
z1
# Out:
# f    1.0
# a    7.0
# c    2.0
# d    2.0
# x    NaN
# y    NaN
# z    NaN
# dtype: float64

# %%
z2 = pd.Series(777, index=list('xyz'))
z2
# Out:
# x    777
# y    777
# z    777
# dtype: int64

# %%
x = pd.Series(np.random.randint(-5, 6, 10), index=list('abcdefghij'))
print(x)
np.mean(x)
# Out:
# a   -3
# b    2
# c    5
# d    5
# e    4
# f    3
# g   -1
# h    5
# i    4
# j    3
# dtype: int64
# 2.7

# %%
data = {i: np.random.randint(10) for i in 'abcdefghij'}
z3 = pd.Series(data)
print(z3)
z3[::2]
# Out:
# a    7
# b    4
# c    1
# d    7
# e    0
# f    1
# g    0
# h    6
# i    4
# j    7
# dtype: int64
# a    7
# c    1
# e    0
# g    0
# i    4
# dtype: int64

# %%
cities['Moscow']
# Out:
# 1000.0

# %%
cities[['Moscow', 'London']] # mind double brackets to look for the list type in the Series
# Out:
# Moscow    1000.0
# London     300.0
# dtype: float64

# %%
cities.keys()
# Out:
# Index(['Moscow', 'London', 'Prague'], dtype='object')

# %%
cities.values
# Out:
# array([1000.,  300.,   nan])

# %%
cities[cities < 1000] # to filter out based on the condition
# Out:
# London    300.0
# dtype: float64

# %%
cities < 1000
# Out:
# Moscow    False
# London     True
# Prague    False
# dtype: bool

# %%
cities['Prague'] = 100
cities
# Out:
# Moscow    1000.0
# London     300.0
# Prague     100.0
# dtype: float64

# %%
cities[(cities < 1000) & (cities > 100)] # multiple conditions using & for AND, | for OR, etc.
# Out:
# London    300.0
# dtype: float64

# %%
cities[cities < 1000] = 3 # assigning based on the condition
cities
# Out:
# Moscow    1000.0
# London       3.0
# Prague       3.0
# dtype: float64

# %%
print(cities * 10) # initial data is kept intact
print(cities)
# Out:
# Moscow    10000.0
# London       30.0
# Prague       30.0
# dtype: float64
# Moscow    1000.0
# London       3.0
# Prague       3.0
# dtype: float64

# %%
d = {'Moscow': 1000, 'London': 300, 'Prague': None}
cities = pd.Series(d)
print(cities)

print(cities[cities.isnull()])
print(cities[cities.notnull()])
# Out:
# Moscow    1000.0
# London     300.0
# Prague       NaN
# dtype: float64
# Prague   NaN
# dtype: float64
# Moscow    1000.0
# London     300.0
# dtype: float64

# %%
s1 = pd.Series(np.arange(5), index=list('abcde'), dtype='float64')
s2 = pd.Series(np.arange(5, 10), index=list('acexy'))
print(s1)
print(s2)
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64
# a    5
# c    6
# e    7
# x    8
# y    9
# dtype: int64

# %%
s1 + s2
# Out:
# a     5.0
# b     NaN
# c     8.0
# d     NaN
# e    11.0
# x     NaN
# y     NaN
# dtype: float64

# %%
# DataFrame

# %%
dict_cities = {'city': ['Moscow', 'London', 'Paris', 'Toronto'], 'population_mln': [12, 9, 2, 3]}
dict_cities
# Out:
# {'city': ['Moscow', 'London', 'Paris', 'Toronto'],
#  'population_mln': [12, 9, 2, 3]}

# %%
df = pd.DataFrame(dict_cities)
df
# Out:
#       city  population_mln
# 0   Moscow              12
# 1   London               9
# 2    Paris               2
# 3  Toronto               3

# %%
my_list = [['Moscow', 'London', 'Paris', 'Toronto'], [12, 9, 2, 3]]
my_list
# Out:
# [['Moscow', 'London', 'Paris', 'Toronto'], [12, 9, 2, 3]]

# %%
# matrix transpose

df2 = pd.DataFrame(my_list)
print(df2)
df2.T
# Out:
#         0       1      2        3
# 0  Moscow  London  Paris  Toronto
# 1      12       9      2        3
#          0   1
# 0   Moscow  12
# 1   London   9
# 2    Paris   2
# 3  Toronto   3

# %%
# working with CSV files

titanic = pd.read_csv('/content/train.csv', index_col=0) # sep=';' to specify ';' as a delimeter
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
titanic.tail(2)
# Out:
#              Survived  Pclass                   Name   Sex   Age  SibSp  \
# PassengerId
# 890                 1       1  Behr, Mr. Karl Howell  male  26.0      0
# 891                 0       3    Dooley, Mr. Patrick  male  32.0      0
#
#              Parch  Ticket   Fare Cabin Embarked
# PassengerId
# 890              0  111369  30.00  C148        C
# 891              0  370376   7.75   NaN        Q

# %%
titanic[1:3]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic.shape
# Out:
# (891, 11)

# %%
titanic.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
titanic[['Survived', 'Pclass']].head(3)
# Out:
#              Survived  Pclass
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3

# %%
titanic_short = pd.read_csv('/content/train.csv', nrows=10, usecols=['Name', 'Sex', 'Survived'], index_col=0)
titanic_short
# Out:
#                                                        Name     Sex
# Survived
# 0                                   Braund, Mr. Owen Harris    male
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1                                    Heikkinen, Miss. Laina  female
# 1              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 0                                  Allen, Mr. William Henry    male
# 0                                          Moran, Mr. James    male
# 0                                   McCarthy, Mr. Timothy J    male
# 0                            Palsson, Master. Gosta Leonard    male
# 1         Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 1                       Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
titanic[['Name', 'Sex']] # addressing columns
# Out:
#                                                           Name     Sex
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
titanic.iloc[1, 2] # addressing rows using indices
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
titanic.loc[2, 'Name'] # addressing rows using labels
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
# implementing conditions

titanic[(titanic['Age'] > 60) & (titanic['Sex'] == 'male')]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 34                  0       2                 Wheadon, Mr. Edward H  male
# 55                  0       1        Ostby, Mr. Engelhart Cornelius  male
# 97                  0       1             Goldschmidt, Mr. George B  male
# 117                 0       3                  Connors, Mr. Patrick  male
# 171                 0       1             Van der hoef, Mr. Wyckoff  male
# 253                 0       1             Stead, Mr. William Thomas  male
# 281                 0       3                      Duane, Mr. Frank  male
# 327                 0       3             Nysveen, Mr. Johan Hansen  male
# 439                 0       1                     Fortune, Mr. Mark  male
# 457                 0       1             Millet, Mr. Francis Davis  male
# 494                 0       1               Artagaveytia, Mr. Ramon  male
# ...

# %%
titanic[titanic['Age'].isnull()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
titanic[titanic['Age'].between(0, 10)]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 8                   0       3            Palsson, Master. Gosta Leonard
# 11                  1       3           Sandstrom, Miss. Marguerite Rut
# 17                  0       3                      Rice, Master. Eugene
# 25                  0       3             Palsson, Miss. Torborg Danira
# 44                  1       2  Laroche, Miss. Simonne Marie Anne Andree
# ...               ...     ...                                       ...
# 828                 1       2                     Mallet, Master. Andre
# 832                 1       2           Richards, Master. George Sibley
# 851                 0       3   Andersson, Master. Sigvard Harald Elias
# 853                 0       3                   Boulos, Miss. Nourelain
# 870                 1       3           Johnson, Master. Harold Theodor
#
#                 Sex   Age  SibSp  Parch           Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
titanic.iloc[::20, :][['Age', 'Name', 'Survived']] # every 20th passenger
# Out:
#               Age                                               Name  Survived
# PassengerId
# 1            22.0                            Braund, Mr. Owen Harris         0
# 21           35.0                               Fynney, Mr. Joseph J         0
# 41           40.0     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)         0
# 61           22.0                              Sirayanian, Mr. Orsen         0
# 81           22.0                               Waelens, Mr. Achille         0
# 101          28.0                            Petranec, Miss. Matilda         0
# 121          21.0                        Hickman, Mr. Stanley George         0
# 141           NaN                      Boulos, Mrs. Joseph (Sultana)         0
# 161          44.0                           Cribb, Mr. John Hatfield         0
# 181           NaN                       Sage, Miss. Constance Gladys         0
# 201          28.0                     Vande Walle, Mr. Nestor Cyriel         0
# ...

# %%
titanic['Embarked'].replace('S', 3)
# doesn't change the initial table; otherwise, use inplace=True as an additional argument in 'replace' function
# Out:
# PassengerId
# 1      3
# 2      C
# 3      3
# 4      3
# 5      3
#       ..
# 887    3
# 888    3
# 889    3
# 890    C
# 891    Q
# Name: Embarked, Length: 891, dtype: object

# %%
titanic.describe() # general statistics
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic['Age'].max()
# Out:
# 80.0

# %%
titanic.describe(include=[np.object])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
titanic['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic.to_csv('train_upd.csv') # additional flags are sep=';', header=True, index=True
